# %% [markdown]
# imports

# %%
# %pip install lime
# Out:
# Requirement already satisfied: lime in c:\users\administrator\anaconda3\lib\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in c:\users\administrator\anaconda3\lib\site-packages (from lime) (3.9.2)
# Requirement already satisfied: numpy in c:\users\administrator\anaconda3\lib\site-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in c:\users\administrator\anaconda3\lib\site-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in c:\users\administrator\anaconda3\lib\site-packages (from lime) (4.66.5)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\administrator\anaconda3\lib\site-packages (from lime) (1.5.1)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\administrator\anaconda3\lib\site-packages (from lime) (0.24.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->lime) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->lime) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->lime) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\administrator\anaconda3\lib\site-packages (from tqdm->lime) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import root_mean_squared_error, r2_score, roc_auc_score, f1_score, precision_recall_curve
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
import xgboost as xgb
import shap
import lime.lime_tabular
sns.set_theme(style="whitegrid", palette="colorblind")
SEED = 42
np.random.seed(SEED)

# %% [markdown]
# Loading data

# %%
df = pd.read_csv(
    "D:/kifiya AI/Insurance-Risk-Analytics-and-predictive-modeling/data/MachineLearningRating_v3.txt",
    sep="|",
    engine="python"
)
print("Rows:", df.shape[0])
# Out:
# Rows: 1000099

# %% [markdown]
# Feature engineering

# %%
df["VehicleAge"] = 2025 - df["RegistrationYear"]
df["VehicleAge"] = df["VehicleAge"].clip(0, 30)
df["LogCustomValue"] = np.log1p(df["CustomValueEstimate"])
df["PremiumPerValue"] = df["TotalPremium"] / (df["CustomValueEstimate"] + 1)

# %% [markdown]
# Missing audit

# %%
miss = df.isna().mean().sort_values(ascending=False)
miss[miss>0]
# Out:
# NumberOfVehiclesInFleet     1.000000e+00
# CrossBorder                 9.993021e-01
# PremiumPerValue             7.795658e-01
# LogCustomValue              7.795658e-01
# CustomValueEstimate         7.795658e-01
# Converted                   6.418385e-01
# Rebuilt                     6.418385e-01
# WrittenOff                  6.418385e-01
# NewVehicle                  1.532808e-01
# Bank                        1.459476e-01
# AccountType                 4.022902e-02
# Gender                      9.536056e-03
# MaritalStatus               8.259182e-03
# make                        5.529453e-04
# VehicleIntroDate            5.529453e-04
# bodytype                    5.529453e-04
# kilowatts                   5.529453e-04
# cubiccapacity               5.529453e-04
# Cylinders                   5.529453e-04
# Model                       5.529453e-04
# NumberOfDoors               5.529453e-04
# VehicleType                 5.529453e-04
# mmcode                      5.529453e-04
# CapitalOutstanding          2.999703e-06
# Section                     9.999010e-07
# CalculatedPremiumPerTerm    9.999010e-07
# ExcessSelected              9.999010e-07
# CoverCategory               9.999010e-07
# CoverType                   9.999010e-07
# CoverGroup                  9.999010e-07
# RegistrationYear            9.999010e-07
# TermFrequency               9.999010e-07
# StatutoryClass              9.999010e-07
# StatutoryRiskType           9.999010e-07
# TotalPremium                9.999010e-07
# TotalClaims                 9.999010e-07
# VehicleAge                  9.999010e-07
# TransactionMonth            9.999010e-07
# Product                     9.999010e-07
# IsVATRegistered             9.999010e-07
# SumInsured                  9.999010e-07
# Citizenship                 9.999010e-07
# LegalType                   9.999010e-07
# Title                       9.999010e-07
# Language                    9.999010e-07
# Country                     9.999010e-07
# TrackingDevice              9.999010e-07
# AlarmImmobiliser            9.999010e-07
# Province                    9.999010e-07
# PostalCode                  9.999010e-07
# PolicyID                    9.999010e-07
# MainCrestaZone              9.999010e-07
# SubCrestaZone               9.999010e-07
# ItemType                    9.999010e-07
# dtype: float64

# %% [markdown]
# Pick columns

# %%
num_cols = ["VehicleAge", "LogCustomValue", "PremiumPerValue", "SumInsured"]
cat_cols = ["Province", "Gender", "VehicleType", "CoverType", "MaritalStatus"]
target_sev = "TotalClaims"
target_prob = "HasClaim"

# %% [markdown]
# Severity dataset

# %%
sev_df = df[df["TotalClaims"] > 0].copy()
sev_df["LogTotalClaims"] = np.log1p(sev_df["TotalClaims"])
X_sev = sev_df[num_cols + cat_cols]
y_sev = sev_df["LogTotalClaims"]

# %% [markdown]
# Probability dataset

# %%
df["HasClaim"] = (df["TotalClaims"] > 0).astype(int)
X_prob = df[num_cols + cat_cols]
y_prob = df["HasClaim"]

# %% [markdown]
# Split

# %%
X_prob_train, X_prob_test, y_prob_train, y_prob_test = train_test_split(
    X_prob, y_prob, test_size=0.2, random_state=SEED, stratify=y_prob)
X_sev_train,  X_sev_test,  y_sev_train,  y_sev_test  = train_test_split(
    X_sev, y_sev,  test_size=0.2, random_state=SEED)

# %% [markdown]
#  Pre-processing pipeline

# %%
numeric_pipe = Pipeline([
    ("impute", SimpleImputer(strategy="median")),
    ("scale",  StandardScaler())
])
cat_pipe = Pipeline([
    ("impute", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])
preprocessor = ColumnTransformer([
    ("num", numeric_pipe, num_cols),
    ("cat", cat_pipe, cat_cols)
])

# %% [markdown]
# LR severity

# %%
lr_sev = Pipeline([("prep", preprocessor),
                   ("model", LinearRegression())])
lr_sev.fit(X_sev_train, y_sev_train)
pred_lr_sev = lr_sev.predict(X_sev_test)
rmse_lr = root_mean_squared_error(y_sev_test, pred_lr_sev)
r2_lr   = r2_score(y_sev_test, pred_lr_sev)
print(f"LR Severity – RMSE: {rmse_lr:.3f} | R²: {r2_lr:.3f}")
# Out:
# LR Severity – RMSE: 0.956 | R²: 0.656

# %% [markdown]
# RF severity

# %%
rf_sev = Pipeline([("prep", preprocessor),
                   ("model", RandomForestRegressor(n_estimators=300,
                                                  max_depth=None,
                                                  random_state=SEED))])
rf_sev.fit(X_sev_train, y_sev_train)
pred_rf_sev = rf_sev.predict(X_sev_test)
rmse_rf = root_mean_squared_error(y_sev_test, pred_rf_sev)
r2_rf   = r2_score(y_sev_test, pred_rf_sev)
print(f"RF Severity – RMSE: {rmse_rf:.3f} | R²: {r2_rf:.3f}")
# Out:
# RF Severity – RMSE: 1.060 | R²: 0.576

# %% [markdown]
# XGB severity

# %%
xgb_sev = Pipeline([("prep", preprocessor),
                    ("model", xgb.XGBRegressor(n_estimators=300,
                                               max_depth=6,
                                               learning_rate=0.1,
                                               random_state=SEED))])
xgb_sev.fit(X_sev_train, y_sev_train)
pred_xgb_sev = xgb_sev.predict(X_sev_test)
rmse_xgb = root_mean_squared_error(y_sev_test, pred_xgb_sev)
r2_xgb   = r2_score(y_sev_test, pred_xgb_sev)
print(f"XGB Severity – RMSE: {rmse_xgb:.3f} | R²: {r2_xgb:.3f}")
# Out:
# XGB Severity – RMSE: 1.048 | R²: 0.586

# %% [markdown]
# Severity leaderboard

# %%
severity_leaderboard = pd.DataFrame({
    "Model": ["LinearRegression", "RandomForest", "XGBoost"],
    "RMSE_log":  [rmse_lr, rmse_rf, rmse_xgb],
    "R2":        [r2_lr, r2_rf, r2_xgb]
}).sort_values("RMSE_log")
severity_leaderboard.style.background_gradient(subset=["RMSE_log"], cmap="Reds")
# Out:
# <style type="text/css">
# #T_e4782_row0_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e4782_row1_col1 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_e4782_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4782">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4782_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e4782_level0_col1" class="col_heading level0 col1" >RMSE_log</th>
#       <th id="T_e4782_level0_col2" class="col_heading level0 col2" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4782_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4782_row0_col0" class="data row0 col0" >LinearRegression</td>
#       <td id="T_e4782_row0_col1" class="data row0 col1" >0.955736</td>
#       <td id="T_e4782_row0_col2" class="data row0 col2" >0.655652</td>
#     </tr>
#     <tr>
#       <th id="T_e4782_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e4782_row1_col0" class="data row1 col0" >XGBoost</td>
#       <td id="T_e4782_row1_col1" class="data row1 col1" >1.047657</td>
#       <td id="T_e4782_row1_col2" class="data row1 col2" >0.586228</td>
#     </tr>
#     <tr>
#       <th id="T_e4782_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_e4782_row2_col0" class="data row2 col0" >RandomForest</td>
#       <td id="T_e4782_row2_col1" class="data row2 col1" >1.060325</td>
#       <td id="T_e4782_row2_col2" class="data row2 col2" >0.576162</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Imbalance

# %%
y_prob_train.value_counts(normalize=True)
# Out:
# HasClaim
# 0    0.997213
# 1    0.002787
# Name: proportion, dtype: float64

# %% [markdown]
# XGB probability

# %%
xgb_clf = Pipeline([("prep", preprocessor),
                    ("model", xgb.XGBClassifier(n_estimators=300,
                                                max_depth=6,
                                                scale_pos_weight=(y_prob_train==0).sum()/(y_prob_train==1).sum(),
                                                random_state=SEED))])
xgb_clf.fit(X_prob_train, y_prob_train)
pred_prob = xgb_clf.predict_proba(X_prob_test)[:,1]
auc = roc_auc_score(y_prob_test, pred_prob)
print(f"XGB Probability – AUC: {auc:.3f}")
# Out:
# XGB Probability – AUC: 0.871

# %% [markdown]
# Combined leaderboard

# %%
summary = pd.concat([
    severity_leaderboard.assign(Task="Severity"),
    pd.DataFrame({"Model":["XGBoost"], "RMSE_log":[np.nan], "R2":[np.nan], "AUC":[auc], "Task":["Probability"]})
], ignore_index=True)
summary
# Out:
#               Model  RMSE_log        R2         Task       AUC
# 0  LinearRegression  0.955736  0.655652     Severity       NaN
# 1           XGBoost  1.047657  0.586228     Severity       NaN
# 2      RandomForest  1.060325  0.576162     Severity       NaN
# 3           XGBoost       NaN       NaN  Probability  0.870588

# %% [markdown]
# Risk-based premium

# %%
features = num_cols + cat_cols

# Subset inputs to exact feature columns
X_prob = df[features]
X_sev = sev_df[features]

prob_claim = xgb_clf.predict_proba(X_prob)[:,1]
sev_claim  = np.expm1(xgb_sev.predict(X_sev))

pricing_df = df.copy()
pricing_df["PredProb"] = prob_claim
pricing_df["PredSev"]  = 0

mask = pricing_df["HasClaim"] == 1
pricing_df.loc[mask, "PredSev"] = sev_claim.values  # make sure indices align or use .values

# For non-claim policies, use mean severity
mean_sev = df.loc[df["HasClaim"]==1, "TotalClaims"].mean()
pricing_df["PredSev"].replace(0, mean_sev, inplace=True)

EXPENSE_LOAD = 250
PROFIT_MARGIN = 0.05
pricing_df["RiskPremium"] = pricing_df["PredProb"] * pricing_df["PredSev"]
pricing_df["SuggestedPremium"] = pricing_df["RiskPremium"] * (1 + PROFIT_MARGIN) + EXPENSE_LOAD
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 8
#       5 X_sev = sev_df[features]
#       7 prob_claim = xgb_clf.predict_proba(X_prob)[:,1]
# ----> 8 sev_claim  = np.expm1(xgb_sev.predict(X_sev))
#      10 pricing_df = df.copy()
#      11 pricing_df["PredProb"] = prob_claim
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\pipeline.py:601, in Pipeline.predict(self, X, **params)
#     599     for _, name, transform in self._iter(with_final=False):
#     600         Xt = transform.transform(Xt)
# --> 601     return self.steps[-1][1].predict(Xt, **params)
#     603 # metadata routing enabled
#     604 routed_params = process_routing(self, "predict", **params)
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\xgboost\sklearn.py:1327, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1325 if self._can_use_inplace_predict():
#    1326     try:
# -> 1327         predts = self.get_booster().inplace_predict(
#    1328             data=X,
#    1329             iteration_range=iteration_range,
#    1330             predict_type="margin" if output_margin else "value",
#    1331             missing=self.missing,
#    1332             base_margin=base_margin,
#    1333             validate_features=validate_features,
#    1334         )
#    1335         if _is_cupy_alike(predts):
#    1336             cp = import_cupy()
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\xgboost\core.py:2677, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2673         raise TypeError(
#    2674             "`shape` attribute is required when `validate_features` is True."
#    2675         )
#    2676     if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2677         raise ValueError(
#    2678             f"Feature shape mismatch, expected: {self.num_features()}, "
#    2679             f"got {data.shape[1]}"
#    2680         )
#    2682 if _is_np_array_like(data):
#    2683     from .data import _ensure_np_dtype
#
# ValueError: Feature shape mismatch, expected: 33, got 51
